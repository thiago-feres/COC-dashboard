# %%
import pandas as pd
df = pd.read_csv("../data/relatorio_detalhado.csv")
df.head(50) # Mostra as 5 primeiras linhas
# Out:
#                name      role  townHallLevel  trophies  warStars  donations  \
# 0           Smok GG    member             12        29        67        313
# 1         Renato649    member             11       191         3          0
# 2      raucho gamer     admin             11        66       142        837
# 3         NOBRU OFC    member             11        51       129        177
# 4         亗Betinha亗  coLeader             11        40       274        584
# 5            vilela    member             10         0        70          0
# 6          matheuss    member             10       139        26        613
# 7              loki    member             11        83         6          0
# 8        ProMaster2     admin              9        40        67         31
# 9       CEO da Yoki    leader             11         0       102        282
# 10     PriviaPlayer    member             11         0        74          0
# ...
